# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/username_password_recovery_code.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Create a view or table

temp_table_name = "username_password_recovery_code_csv"

df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `username_password_recovery_code_csv`
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "username_password_recovery_code_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Importing pyspark Lib.
import pyspark

#Making spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Assignment').getOrCreate()

#About Spark
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=892183418903091#setting/sparkui/0805-041721-ck6wn1yk/driver-6618396197105612643">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#Reading single File
df1 = spark.read.format("csv").option("inferSchema", True).option("header", True).option("sep",";").load("/FileStore/tables/username_password_recovery_code.csv")

display(df1)

print(df1.count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df1.printSchema()
# Out:
# root
#  |-- Username: string (nullable = true)
#  |--  Identifier: integer (nullable = true)
#  |-- One-time password: string (nullable = true)
#  |-- Recovery code: string (nullable = true)
#  |-- First name: string (nullable = true)
#  |-- Last name: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Location: string (nullable = true)

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
schema_defined= StructType([StructField('Username', StringType(), True),
                              StructField('Identifier', IntegerType(), True),
                             StructField('Recovery code', StringType(),True),
                             StructField('First name', StringType(),True),
                              StructField('Last name', StringType(),True),
                               StructField('Department', StringType(),True),
                              StructField('Location', StringType(),True),
                            ])

# %%
df= spark.read.format("csv").schema(schema_defined).option("header", True ).option("sep",";").load("/FileStore/tables/username_password_recovery_code.csv")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.parquet("/FileStore/tables/username_password_recovery_code.parquet")

# %%
df.show()
# Out:
# +---------+----------+-------------+----------+---------+----------+-----------+
# | Username|Identifier|Recovery code|First name|Last name|Department|   Location|
# +---------+----------+-------------+----------+---------+----------+-----------+
# | booker12|      9012|       12se74|    rb9012|   Rachel|    Booker|      Sales|
# |   grey07|      2070|       04ap67|    lg2070|    Laura|      Grey|      Depot|
# |johnson81|      4081|       30no86|    cj4081|    Craig|   Johnson|      Depot|
# |jenkins46|      9346|       14ju73|    mj9346|     Mary|   Jenkins|Engineering|
# |  smith79|      5079|       09ja61|    js5079|    Jamie|     Smith|Engineering|
# +---------+----------+-------------+----------+---------+----------+-----------+
